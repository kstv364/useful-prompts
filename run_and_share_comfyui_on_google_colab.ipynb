# %% [markdown]
# <a href="https://colab.research.google.com/github/kstv364/useful-prompts/blob/main/run_and_share_comfyui_on_google_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Running ComfyUI in Google Colab
#
# To run ComfyUI in Google Colab, you need to enable GPU acceleration. Go to "Runtime" -> "Change runtime type" and select "GPU" as the hardware accelerator.

# %%
# Update package lists and install necessary packages
# !apt-get update
# !apt-get install -y wget aria2 libgl1-mesa-glx
# Out:
# Hit:1 https://cli.github.com/packages stable InRelease
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Hit:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Get:4 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Hit:5 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:7 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:8 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Get:9 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,816 kB]
# Get:10 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [3,473 kB]
# Hit:11 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Get:12 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,594 kB]
# ...

# %%
# !git clone -b MAC-Linux https://github.com/Tavris1/ComfyUI-Easy-Install.git
# Out:
# Cloning into 'ComfyUI-Easy-Install'...
# remote: Enumerating objects: 1265, done.
# remote: Counting objects: 100% (449/449), done.
# remote: Compressing objects: 100% (188/188), done.
# remote: Total 1265 (delta 391), reused 270 (delta 259), pack-reused 816 (from 3)
# Receiving objects: 100% (1265/1265), 9.21 MiB | 20.20 MiB/s, done.
# Resolving deltas: 100% (706/706), done.

# %%
# !cd ComfyUI-Easy-Install && chmod +x ComfyUI-Easy-Install-Linux.sh

# %%
# !cd ComfyUI-Easy-Install && ./ComfyUI-Easy-Install-Linux.sh
# Out:
# WARNING: Running as root in a container environment.
# This is allowed for Proxmox LXC containers.
# It's recommended to create a non-root user after installation.
# ::::::::::::::: Initializing pip ::::::::::::::
# ::::::::::::::: Clearing Pip Cache ::::::::::::::
# WARNING: No matching packages
# Files removed: 0
# ::::::::::::::: Installing System Dependencies ::::::::::::::
# Hit:1 https://cli.github.com/packages stable InRelease
# Hit:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:3 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:4 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:5 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:6 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Get:7 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Hit:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# ...

# %%
# Install the pinggy library for creating public URLs
# !pip install pinggy
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 24.3 MB/s  0:00:00
# ...

# %%
# Start a pinggy tunnel to forward traffic from a public URL to localhost:8188
import pinggy
tunnel1 = pinggy.start_tunnel(
    forwardto="localhost:8188",
)

# Print the URLs of the started tunnel
print(f"Tunnel1 started - URLs: {tunnel1.urls}")
# Out:
# Tunnel1 started - URLs: ['http://iaklr-136-117-207-123.a.free.pinggy.link', 'https://iaklr-136-117-207-123.a.free.pinggy.link']

# %%
# %cd /content/ComfyUI-Easy-Install/ComfyUI-Easy-Install/ComfyUI/
# !python main.py --listen 0.0.0.0
# Out:
# /content/ComfyUI-Easy-Install/ComfyUI-Easy-Install/ComfyUI
# [START] Security scan
# [DONE] Security scan
# ## ComfyUI-Manager: installing dependencies done.
# ** ComfyUI startup time: 2025-10-27 05:00:02.699
# ** Platform: Linux
# ** Python version: 3.12.12 (main, Oct 10 2025, 08:52:57) [GCC 11.4.0]
# ** Python executable: /usr/bin/python3
# ** ComfyUI Path: /content/ComfyUI-Easy-Install/ComfyUI-Easy-Install/ComfyUI
# ** ComfyUI Base Folder Path: /content/ComfyUI-Easy-Install/ComfyUI-Easy-Install/ComfyUI
# ** User directory: /content/ComfyUI-Easy-Install/ComfyUI-Easy-Install/ComfyUI/user
# ** ComfyUI-Manager config path: /content/ComfyUI-Easy-Install/ComfyUI-Easy-Install/ComfyUI/user/default/ComfyUI-Manager/config.ini
# ** Log path: /content/ComfyUI-Easy-Install/ComfyUI-Easy-Install/ComfyUI/user/comfyui.log
#
# Prestartup times for custom nodes:
#    0.0 seconds: /content/ComfyUI-Easy-Install/ComfyUI-Easy-Install/ComfyUI/custom_nodes/rgthree-comfy
# ...
